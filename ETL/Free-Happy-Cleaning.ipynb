# %%
# Import dependencies
import pandas as pd

# %%
# Load raw data files
Happy_df = pd.read_csv(r"C:\Users\josep\Free-And-Happy\resources\freedom_scores.csv")
Free_df = pd.read_csv(r"C:\Users\josep\Free-And-Happy\resources\happiness-cantril-ladder.csv")

# %%
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  2006
# 1     Afghanistan  AFG  2007
# 2     Afghanistan  AFG  2008
# 3     Afghanistan  AFG  2009
# 4     Afghanistan  AFG  2010
# ...           ...  ...   ...
# 2239     Zimbabwe  ZWE  2016
# 2240     Zimbabwe  ZWE  2017
# 2241     Zimbabwe  ZWE  2018
# 2242     Zimbabwe  ZWE  2019
# 2243     Zimbabwe  ZWE  2020
#
#       Life satisfaction in Cantril Ladder (World Happiness Report 2022)
# 0                                              3.723590
# 1                                              4.401778
# 2                                              4.758381
# 3                                              3.831719
# 4                                              3.782938
# ...                                                 ...
# 2239                                           3.616480
# 2240                                           2.693523
# 2241                                           3.159802
# ...
